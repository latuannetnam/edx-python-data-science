# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001CCE67E1438>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-06-18T10:25:18Z',
#   'created_at': '2017-06-18T10:21:56Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#INDvPAK',
#     'promoted_content': None,
#     'query': '%23INDvPAK',
#     'tweet_volume': 157285,
#     'url': 'http://twitter.com/search?q=%23INDvPAK'},
#    {'name': '#FathersDay',
#     'promoted_content': None,
#     'query': '%23FathersDay',
#     'tweet_volume': 181055,
#     'url': 'http://twitter.com/search?q=%23FathersDay'},
#    {'name': '#BabalarGünü',
#     'promoted_content': None,
#     'query': '%23BabalarG%C3%BCn%C3%BC',
#     'tweet_volume': 60787,
#     'url': 'http://twitter.com/search?q=%23BabalarG%C3%BCn%C3%BC'},
#    {'name': '#lys3',
#     'promoted_content': None,
#     'query': '%23lys3',
#     'tweet_volume': 16038,
#     'url': 'http://twitter.com/search?q=%23lys3'},
#    {'name': '#Marr',
#     'promoted_content': None,
#     'query': '%23Marr',
#     'tweet_volume': 18249,
#     'url': 'http://twitter.com/search?q=%23Marr'},
#    {'name': 'Fakhar',
#     'promoted_content': None,
#     'query': 'Fakhar',
#     'tweet_volume': 14849,
#     'url': 'http://twitter.com/search?q=Fakhar'},
#    {'name': '매그너스',
#     'promoted_content': None,
#     'query': '%EB%A7%A4%EA%B7%B8%EB%84%88%EC%8A%A4',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%EB%A7%A4%EA%B7%B8%EB%84%88%EC%8A%A4'},
#    {'name': '内閣支持率36',
#     'promoted_content': None,
#     'query': '%E5%86%85%E9%96%A3%E6%94%AF%E6%8C%81%E7%8E%8736',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E5%86%85%E9%96%A3%E6%94%AF%E6%8C%81%E7%8E%8736'},
#    {'name': 'Pedrógão Grande',
#     'promoted_content': None,
#     'query': '%22Pedr%C3%B3g%C3%A3o+Grande%22',
#     'tweet_volume': 20586,
#     'url': 'http://twitter.com/search?q=%22Pedr%C3%B3g%C3%A3o+Grande%22'},
#    {'name': 'Ant McPartlin',
#     'promoted_content': None,
#     'query': '%22Ant+McPartlin%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Ant+McPartlin%22'},
#    {'name': 'Jackie Chan',
#     'promoted_content': None,
#     'query': '%22Jackie+Chan%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jackie+Chan%22'},
#    {'name': 'Porsche',
#     'promoted_content': None,
#     'query': 'Porsche',
#     'tweet_volume': 39945,
#     'url': 'http://twitter.com/search?q=Porsche'},
#    {'name': 'Find Laxmans Brother',
#     'promoted_content': None,
#     'query': '%22Find+Laxmans+Brother%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Find+Laxmans+Brother%22'},
#    {'name': '亀井さん',
#     'promoted_content': None,
#     'query': '%E4%BA%80%E4%BA%95%E3%81%95%E3%82%93',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E4%BA%80%E4%BA%95%E3%81%95%E3%82%93'},
#    {'name': '#Peston',
#     'promoted_content': None,
#     'query': '%23Peston',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Peston'},
#    {'name': '#Portugal',
#     'promoted_content': None,
#     'query': '%23Portugal',
#     'tweet_volume': 30515,
#     'url': 'http://twitter.com/search?q=%23Portugal'},
#    {'name': '#FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FelizDomingo'},
#    {'name': '#تغريده_فيها_ذكر_الله',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87_%D9%81%D9%8A%D9%87%D8%A7_%D8%B0%D9%83%D8%B1_%D8%A7%D9%84%D9%84%D9%87',
#     'tweet_volume': 18250,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87_%D9%81%D9%8A%D9%87%D8%A7_%D8%B0%D9%83%D8%B1_%D8%A7%D9%84%D9%84%D9%87'},
#    {'name': '#FeteDesPeres',
#     'promoted_content': None,
#     'query': '%23FeteDesPeres',
#     'tweet_volume': 10449,
#     'url': 'http://twitter.com/search?q=%23FeteDesPeres'},
#    {'name': '#JHMSMiniTrails',
#     'promoted_content': None,
#     'query': '%23JHMSMiniTrails',
#     'tweet_volume': 16321,
#     'url': 'http://twitter.com/search?q=%23JHMSMiniTrails'},
#    {'name': '#يوم_الاب',
#     'promoted_content': None,
#     'query': '%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%A7%D8%A8',
#     'tweet_volume': 81185,
#     'url': 'http://twitter.com/search?q=%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%A7%D8%A8'},
#    {'name': '#البنك_الاهلي_يوخر_الرواتب',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%A8%D9%86%D9%83_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D9%8A%D9%88%D8%AE%D8%B1_%D8%A7%D9%84%D8%B1%D9%88%D8%A7%D8%AA%D8%A8',
#     'tweet_volume': 46218,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A8%D9%86%D9%83_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D9%8A%D9%88%D8%AE%D8%B1_%D8%A7%D9%84%D8%B1%D9%88%D8%A7%D8%AA%D8%A8'},
#    {'name': '#TheVoiceAU',
#     'promoted_content': None,
#     'query': '%23TheVoiceAU',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TheVoiceAU'},
#    {'name': '#鉄腕DASH',
#     'promoted_content': None,
#     'query': '%23%E9%89%84%E8%85%95DASH',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E9%89%84%E8%85%95DASH'},
#    {'name': '#vaderdag',
#     'promoted_content': None,
#     'query': '%23vaderdag',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23vaderdag'},
#    {'name': '#18juin',
#     'promoted_content': None,
#     'query': '%2318juin',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2318juin'},
#    {'name': '#AVoté',
#     'promoted_content': None,
#     'query': '%23AVot%C3%A9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AVot%C3%A9'},
#    {'name': '#ReinventMemories',
#     'promoted_content': None,
#     'query': '%23ReinventMemories',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ReinventMemories'},
#    {'name': '#MaliaAndTristanAtSMRosario',
#     'promoted_content': None,
#     'query': '%23MaliaAndTristanAtSMRosario',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MaliaAndTristanAtSMRosario'},
#    {'name': '#ASKERİMİZEHİRLEME',
#     'promoted_content': None,
#     'query': '%23ASKER%C4%B0M%C4%B0ZEH%C4%B0RLEME',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ASKER%C4%B0M%C4%B0ZEH%C4%B0RLEME'},
#    {'name': '#あなたの名前だけ見て勝手に想像してみる',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%90%8D%E5%89%8D%E3%81%A0%E3%81%91%E8%A6%8B%E3%81%A6%E5%8B%9D%E6%89%8B%E3%81%AB%E6%83%B3%E5%83%8F%E3%81%97%E3%81%A6%E3%81%BF%E3%82%8B',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%90%8D%E5%89%8D%E3%81%A0%E3%81%91%E8%A6%8B%E3%81%A6%E5%8B%9D%E6%89%8B%E3%81%AB%E6%83%B3%E5%83%8F%E3%81%97%E3%81%A6%E3%81%BF%E3%82%8B'},
#    {'name': '#39CongesoPSOE',
#     'promoted_content': None,
#     'query': '%2339CongesoPSOE',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2339CongesoPSOE'},
#    {'name': '#WorstWaysToStartALoveLetter',
#     'promoted_content': None,
#     'query': '%23WorstWaysToStartALoveLetter',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23WorstWaysToStartALoveLetter'},
#    {'name': '#BuonaDomenica',
#     'promoted_content': None,
#     'query': '%23BuonaDomenica',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BuonaDomenica'},
#    {'name': '#OJKKeuanganSyariah',
#     'promoted_content': None,
#     'query': '%23OJKKeuanganSyariah',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23OJKKeuanganSyariah'},
#    {'name': '#خليه_العبدلي',
#     'promoted_content': None,
#     'query': '%23%D8%AE%D9%84%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D8%A8%D8%AF%D9%84%D9%8A',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AE%D9%84%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D8%A8%D8%AF%D9%84%D9%8A'},
#    {'name': '#パワスプ',
#     'promoted_content': None,
#     'query': '%23%E3%83%91%E3%83%AF%E3%82%B9%E3%83%97',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%83%91%E3%83%AF%E3%82%B9%E3%83%97'},
#    {'name': '#BogotaEstoyContigo',
#     'promoted_content': None,
#     'query': '%23BogotaEstoyContigo',
#     'tweet_volume': 24514,
#     'url': 'http://twitter.com/search?q=%23BogotaEstoyContigo'},
#    {'name': '#SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': 18406,
#     'url': 'http://twitter.com/search?q=%23SundayMorning'},
#    {'name': '#AFLDogsDees',
#     'promoted_content': None,
#     'query': '%23AFLDogsDees',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AFLDogsDees'},
#    {'name': '#JeremstarDay',
#     'promoted_content': None,
#     'query': '%23JeremstarDay',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JeremstarDay'},
#    {'name': '#bbcsp',
#     'promoted_content': None,
#     'query': '%23bbcsp',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23bbcsp'},
#    {'name': '#NRLEelsDragons',
#     'promoted_content': None,
#     'query': '%23NRLEelsDragons',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NRLEelsDragons'},
#    {'name': '#k1_wgp',
#     'promoted_content': None,
#     'query': '%23k1_wgp',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23k1_wgp'},
#    {'name': '#Woronicza17',
#     'promoted_content': None,
#     'query': '%23Woronicza17',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Woronicza17'},
#    {'name': '#LoseALetterSpoilASong',
#     'promoted_content': None,
#     'query': '%23LoseALetterSpoilASong',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LoseALetterSpoilASong'},
#    {'name': '#KyivPride2017',
#     'promoted_content': None,
#     'query': '%23KyivPride2017',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23KyivPride2017'},
#    {'name': '#غتر_كاستل_سر_جاذبيتك',
#     'promoted_content': None,
#     'query': '%23%D8%BA%D8%AA%D8%B1_%D9%83%D8%A7%D8%B3%D8%AA%D9%84_%D8%B3%D8%B1_%D8%AC%D8%A7%D8%B0%D8%A8%D9%8A%D8%AA%D9%83',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%BA%D8%AA%D8%B1_%D9%83%D8%A7%D8%B3%D8%AA%D9%84_%D8%B3%D8%B1_%D8%AC%D8%A7%D8%B0%D8%A8%D9%8A%D8%AA%D9%83'},
#    {'name': '#HappyBirthdayJoshDun',
#     'promoted_content': None,
#     'query': '%23HappyBirthdayJoshDun',
#     'tweet_volume': 22783,
#     'url': 'http://twitter.com/search?q=%23HappyBirthdayJoshDun'},
#    {'name': '#الجناح_الملكي_بنارسس',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%AC%D9%86%D8%A7%D8%AD_%D8%A7%D9%84%D9%85%D9%84%D9%83%D9%8A_%D8%A8%D9%86%D8%A7%D8%B1%D8%B3%D8%B3',
#     'tweet_volume': 10643,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AC%D9%86%D8%A7%D8%AD_%D8%A7%D9%84%D9%85%D9%84%D9%83%D9%8A_%D8%A8%D9%86%D8%A7%D8%B1%D8%B3%D8%B3'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'created_at', 'locations', 'as_of']
# [{'url': 'http://twitter.com/search?q=%23DHS17', 'promoted_content': None, 'tweet_volume': None, 'query': '%23DHS17', 'name': '#DHS17'}, {'url': 'http://twitter.com/search?q=%23LetsGoPadres', 'promoted_content': None, 'tweet_volume': None, 'query': '%23LetsGoPadres', 'name': '#LetsGoPadres'}, {'url': 'http://twitter.com/search?q=%23FathersDay', 'promoted_content': None, 'tweet_volume': 181055, 'query': '%23FathersDay', 'name': '#FathersDay'}, {'url': 'http://twitter.com/search?q=%22USS+Fitzgerald%22', 'promoted_content': None, 'tweet_volume': 88300, 'query': '%22USS+Fitzgerald%22', 'name': 'USS Fitzgerald'}, {'url': 'http://twitter.com/search?q=%23WeekendCountdown', 'promoted_content': None, 'tweet_volume': None, 'query': '%23WeekendCountdown', 'name': '#WeekendCountdown'}, {'url': 'http://twitter.com/search?q=%22Bill+Cosby%22', 'promoted_content': None, 'tweet_volume': 203598, 'query': '%22Bill+Cosby%22', 'name': 'Bill Cosby'}, {'url': 'http://twitter.com/search?q=%23MAGA', 'promoted_content': None, 'tweet_volume': 106761, 'query': '%23MAGA', 'name': '#MAGA'}, {'url': 'http://twitter.com/search?q=%22Andre+Ward%22', 'promoted_content': None, 'tweet_volume': 23413, 'query': '%22Andre+Ward%22', 'name': 'Andre Ward'}, {'url': 'http://twitter.com/search?q=%222+Porsche%22', 'promoted_content': None, 'tweet_volume': None, 'query': '%222+Porsche%22', 'name': '2 Porsche'}, {'url': 'http://twitter.com/search?q=%22Pamela+Anderson%22', 'promoted_content': None, 'tweet_volume': None, 'query': '%22Pamela+Anderson%22', 'name': 'Pamela Anderson'}, {'url': 'http://twitter.com/search?q=%22Remy+and+Nicki%22', 'promoted_content': None, 'tweet_volume': None, 'query': '%22Remy+and+Nicki%22', 'name': 'Remy and Nicki'}, {'url': 'http://twitter.com/search?q=%22Feliz+D%C3%ADa%22', 'promoted_content': None, 'tweet_volume': 82027, 'query': '%22Feliz+D%C3%ADa%22', 'name': 'Feliz Día'}, {'url': 'http://twitter.com/search?q=%22No+Frauds%22', 'promoted_content': None, 'tweet_volume': None, 'query': '%22No+Frauds%22', 'name': 'No Frauds'}, {'url': 'http://twitter.com/search?q=Raubahn', 'promoted_content': None, 'tweet_volume': None, 'query': 'Raubahn', 'name': 'Raubahn'}, {'url': 'http://twitter.com/search?q=%22Queen+of+Rap%22', 'promoted_content': None, 'tweet_volume': None, 'query': '%22Queen+of+Rap%22', 'name': 'Queen of Rap'}, {'url': 'http://twitter.com/search?q=Tupac', 'promoted_content': None, 'tweet_volume': 133402, 'query': 'Tupac', 'name': 'Tupac'}, {'url': 'http://twitter.com/search?q=Fultz', 'promoted_content': None, 'tweet_volume': 117853, 'query': 'Fultz', 'name': 'Fultz'}, {'url': 'http://twitter.com/search?q=%22Whole+Foods%22', 'promoted_content': None, 'tweet_volume': 58084, 'query': '%22Whole+Foods%22', 'name': 'Whole Foods'}, {'url': 'http://twitter.com/search?q=%22Justin+Thomas%22', 'promoted_content': None, 'tweet_volume': 23324, 'query': '%22Justin+Thomas%22', 'name': 'Justin Thomas'}, {'url': 'http://twitter.com/search?q=%22Wild+Thoughts%22', 'promoted_content': None, 'tweet_volume': 59409, 'query': '%22Wild+Thoughts%22', 'name': 'Wild Thoughts'}, {'url': 'http://twitter.com/search?q=Cuba', 'promoted_content': None, 'tweet_volume': 283035, 'query': 'Cuba', 'name': 'Cuba'}, {'url': 'http://twitter.com/search?q=Sixers', 'promoted_content': None, 'tweet_volume': 95113, 'query': 'Sixers', 'name': 'Sixers'}, {'url': 'http://twitter.com/search?q=Celtics', 'promoted_content': None, 'tweet_volume': 93293, 'query': 'Celtics', 'name': 'Celtics'}, {'url': 'http://twitter.com/search?q=%23INDvPAK', 'promoted_content': None, 'tweet_volume': 157285, 'query': '%23INDvPAK', 'name': '#INDvPAK'}, {'url': 'http://twitter.com/search?q=%23WorstWaysToStartALoveLetter', 'promoted_content': None, 'tweet_volume': None, 'query': '%23WorstWaysToStartALoveLetter', 'name': '#WorstWaysToStartALoveLetter'}, {'url': 'http://twitter.com/search?q=%23GoAskDad', 'promoted_content': None, 'tweet_volume': None, 'query': '%23GoAskDad', 'name': '#GoAskDad'}, {'url': 'http://t ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23INDvPAK",
#     "promoted_content": null,
#     "tweet_volume": 157285,
#     "query": "%23INDvPAK",
#     "name": "#INDvPAK"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WorstWaysToStartALoveLetter",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23WorstWaysToStartALoveLetter",
#     "name": "#WorstWaysToStartALoveLetter"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GoAskDad",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23GoAskDad",
#     "name": "#GoAskDad"
#    },
#    {
#     "url": "http://twitter.com/search?q=%234WordDisappointments",
#     "promoted_content": null,
#     "tweet_volume": 32298,
#     "query": "%234WordDisappointments",
#     "name": "#4WordDisappointments"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WhatImKnownFor",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23WhatImKnownFor",
#     "name": "#WhatImKnownFor"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Andre+Ward%22",
#     "promoted_content": null,
#     "tweet_volume": 23413,
#     "query": "%22Andre+Ward%22",
#     "name": "Andre Ward"
#    },
#    {
#     "url": "http://twitter.com/search?q=%222+Porsche%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%222+Porsche%22",
#     "name": "2 Porsche"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pamela+Anderson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Pamela+Anderson%22",
#     "name": "Pamela Anderson"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Remy+and+Nicki%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Remy+and+Nicki%22",
#     "name": "Remy and Nicki"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Feliz+D%C3%ADa%22",
#     "promoted_content": null,
#     "tweet_volume": 82027,
#     "query": "%22Feliz+D%C3%ADa%22",
#     "name": "Feliz D\u00eda"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Happy+Father%27s+Day+Dad%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Happy+Father%27s+Day+Dad%22",
#     "name": "Happy Father's Day Dad"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22No+Frauds%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22No+Frauds%22",
#     "name": "No Frauds"
#    },
#    {
#     "url": "http://twitter.com/search?q=Raubahn",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "Raubahn",
#     "name": "Raubahn"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Queen+of+Rap%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Queen+of+Rap%22",
#     "name": "Queen of Rap"
#    },
#    {
#     "url": "http://twitter.com/search?q=Tupac",
#     "promoted_content": null,
#     "tweet_volume": 133402,
#     "query": "Tupac",
#     "name": "Tupac"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bill+Cosby%22",
#     "promoted_content": null,
#     "tweet_volume": 203598,
#     "query": "%22Bill+Cosby%22",
#     "name": "Bill Cosby"
#    },
#    {
#     "url": "http://twitter.com/search?q=Fultz",
#     "promoted_content": null,
#     "tweet_volume": 117853,
#     "query": "Fultz",
#     "name": "Fultz"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Whole+Foods%22",
#     "promoted_content": null,
#     "tweet_volume": 58084,
#     "query": "%22Whole+Foods%22",
#     "name": "Whole Foods"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Justin+Thomas%22",
#     "promoted_content": null,
#     "tweet_volume": 23324,
#     "query": "%22Justin+Thomas%22",
#     "name": "Justin Thomas"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Wild+Thoughts%22",
#     "promoted_content": null,
#     "tweet_volume": 59409,
#     "query": "%22Wild+Thoughts%22",
#     "name": "Wild Thoughts"
#    },
#    {
#     "url": "http://twitter.com/search?q=Cuba",
#     "promoted_content": null,
#     "tweet_volume": 283035,
#     "query": "Cuba",
#     "name": "Cuba"
#    },
#    {
#     "url": "http://twitter.com/search?q=%22USS+Fitzgerald%22",
#     "promoted_content": null,
#     "tweet_volume": 88300,
#     "query": "%22USS+Fitzgerald%22",
#     "name": "USS Fitzgerald"
#    },
#    {
#     "url": "http://twitter.com/search?q=Sixers",
#     "promoted_content": null,
#     "tweet_volume": 95113,
#     "query": "Sixers",
#     "name": "Sixers"
#    },
#    {
#     "url": "http://twitter.com/search?q=Celtics",
#     "promoted_content": null,
#     "tweet_volume": 93293,
#     "query": "Celtics",
#     "name": "Celtics"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LoseALetterSpoilASong",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23LoseALetterSpoilASong",
#     "name": "#LoseALetterSpoilASong"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LupinThe3rd",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23LupinThe3rd",
#     "name": "#LupinThe3rd"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SundayMorning",
#     "promoted_content": null,
#     "tweet_volume": 18406,
#     "query": "%23SundayMorning",
#     "name": "#SundayMorning"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ShakespeareSunday",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23ShakespeareSunday",
#     "name": "#ShakespeareSunday"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Beyonce",
#     "promoted_content": null,
#     "tweet_volume": 13407,
#     "query": "%23Beyonce",
#     "name": "#Beyonce"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PAS17",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PAS17",
#     "name": "#PAS17"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HunterXHunter",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23HunterXHunter",
#     "name": "#HunterXHunter"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TokyoGhoul",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TokyoGhoul",
#     "name": "#TokyoGhoul"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23iHeartEDC",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23iHeartEDC",
#     "name": "#iHeartEDC"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ForzaRC",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23ForzaRC",
#     "name": "#ForzaRC"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WhySurvivorsDontReport",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23WhySurvivorsDontReport",
#     "name": "#WhySurvivorsDontReport"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PhilandoCastile",
#     "promoted_content": null,
#     "tweet_volume": 130664,
#     "query": "%23PhilandoCastile",
#     "name": "#PhilandoCastile"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WaysToAnnoyYourDad",
#     "promoted_content": null,
#     "tweet_volume": 16802,
#     "query": "%23WaysToAnnoyYourDad",
#     "name": "#WaysToAnnoyYourDad"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UFCSingapore",
#     "promoted_content": null,
#     "tweet_volume": 36373,
#     "query": "%23UFCSingapore",
#     "name": "#UFCSingapore"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlackLivesMatter",
#     "promoted_content": null,
#     "tweet_volume": 42055,
#     "query": "%23BlackLivesMatter",
#     "name": "#BlackLivesMatter"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CEO2017",
#     "promoted_content": null,
#     "tweet_volume": 10460,
#     "query": "%23CEO2017",
#     "name": "#CEO2017"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MyEvilTwinWould",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23MyEvilTwinWould",
#     "name": "#MyEvilTwinWould"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TurnAMC",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TurnAMC",
#     "name": "#TurnAMC"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MostRequestedLive",
#     "promoted_content": null,
#     "tweet_volume": 186713,
#     "query": "%23MostRequestedLive",
#     "name": "#MostRequestedLive"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SailBoston",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23SailBoston",
#     "name": "#SailBoston"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WhatWomenWantIn4Words",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23WhatWomenWantIn4Words",
#     "name": "#WhatWomenWantIn4Words"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LivePD",
#     "promoted_content": null,
#     "tweet_volume": 23132,
#     "query": "%23LivePD",
#     "name": "#LivePD"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Kiss108KissConcert",
#     "promoted_content": null,
#     "tweet_volume": 35667,
#     "query": "%23Kiss108KissConcert",
#     "name": "#Kiss108KissConcert"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NationalMascotDay",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23NationalMascotDay",
#     "name": "#NationalMascotDay"
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Caturday",
#     "promoted_content": null,
#     "tweet_volume": 12945,
#     "query": "%23Caturday",
#     "name": "#Caturday"
#    }
#   ],
#   "created_at": "2017-06-18T10:21:56Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ],
#   "as_of": "2017-06-18T10:25:19Z"
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Ant McPartlin,#تغريده_فيها_ذكر_الله,#bbcsp,매그너스,#18juin,#FelizDomingo,#FathersDay,#ReinventMemories,#KyivPride2017,#HappyBirthdayJoshDun,#LoseALetterSpoilASong,#BabalarGünü,Porsche,#خليه_العبدلي,#INDvPAK,Pedrógão Grande,#AVoté,#vaderdag,#lys3,#البنك_الاهلي_يوخر_الرواتب,内閣支持率36,#OJKKeuanganSyariah,#BogotaEstoyContigo,亀井さん,#SundayMorning,Find Laxmans Brother,#NRLEelsDragons,#k1_wgp,#MaliaAndTristanAtSMRosario,#يوم_الاب,#Marr,#Portugal,Jackie Chan,Fakhar,#WorstWaysToStartALoveLetter,#AFLDogsDees,#JeremstarDay,#BuonaDomenica,#39CongesoPSOE,#Woronicza17,#あなたの名前だけ見て勝手に想像してみる,#الجناح_الملكي_بنارسس,#FeteDesPeres,#ASKERİMİZEHİRLEME,#パワスプ,#Peston,#鉄腕DASH,#غتر_كاستل_سر_جاذبيتك,#TheVoiceAU,#JHMSMiniTrails
# ('----------', 'us')
# Bill Cosby,Whole Foods,#4WordDisappointments,Fultz,Celtics,#ForzaRC,#GoAskDad,No Frauds,#MostRequestedLive,#iHeartEDC,Tupac,#ShakespeareSunday,#SailBoston,#LoseALetterSpoilASong,Feliz Día,Andre Ward,Pamela Anderson,#Kiss108KissConcert,#INDvPAK,USS Fitzgerald,#WhatImKnownFor,Sixers,#SundayMorning,#WhatWomenWantIn4Words,Wild Thoughts,#Caturday,#WaysToAnnoyYourDad,#Beyonce,#WorstWaysToStartALoveLetter,#LivePD,#PhilandoCastile,2 Porsche,Raubahn,Happy Father's Day Dad,#UFCSingapore,Justin Thomas,#WhySurvivorsDontReport,Cuba,#HunterXHunter,Remy and Nicki,#TokyoGhoul,#BlackLivesMatter,#LupinThe3rd,#PAS17,Queen of Rap,#CEO2017,#NationalMascotDay,#TurnAMC,#MyEvilTwinWould
# ('----------', 'san diego')
# Bill Cosby,#LetsGoPadres,Whole Foods,Fultz,#DHS17,Celtics,#FathersDay,#ForzaRC,No Frauds,#GoAskDad,#MostRequestedLive,#iHeartEDC,Tupac,#ShakespeareSunday,#MAGA,#LoseALetterSpoilASong,#SailBoston,Feliz Día,Andre Ward,Pamela Anderson,#Kiss108KissConcert,#INDvPAK,USS Fitzgerald,#WhatImKnownFor,Sixers,#SundayMorning,#WhatWomenWantIn4Words,Wild Thoughts,#WaysToAnnoyYourDad,#Beyonce,#WorstWaysToStartALoveLetter,#LivePD,#PhilandoCastile,2 Porsche,Raubahn,#WeekendCountdown,#UFCSingapore,Justin Thomas,#WhySurvivorsDontReport,Cuba,#HunterXHunter,Remy and Nicki,#TokyoGhoul,#BlackLivesMatter,#LupinThe3rd,#PAS17,Queen of Rap,#CEO2017,#TurnAMC,#MyEvilTwinWould

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#INDvPAK', '#WorstWaysToStartALoveLetter', '#LoseALetterSpoilASong', '#SundayMorning'}
# ('==========', 'intersection of us and san-diego')
# {'Bill Cosby', 'Whole Foods', 'Fultz', 'Celtics', '#ForzaRC', '#GoAskDad', 'No Frauds', '#MostRequestedLive', '#iHeartEDC', '#ShakespeareSunday', 'Tupac', '#SailBoston', '#LoseALetterSpoilASong', 'Feliz Día', 'Andre Ward', 'Pamela Anderson', '#Kiss108KissConcert', '#INDvPAK', 'USS Fitzgerald', '#WhatImKnownFor', 'Sixers', '#SundayMorning', '#WhatWomenWantIn4Words', 'Wild Thoughts', '#WaysToAnnoyYourDad', '#Beyonce', '#WorstWaysToStartALoveLetter', '#LivePD', '#PhilandoCastile', '2 Porsche', 'Raubahn', '#UFCSingapore', 'Justin Thomas', '#WhySurvivorsDontReport', 'Cuba', '#HunterXHunter', 'Remy and Nicki', '#TokyoGhoul', '#BlackLivesMatter', '#LupinThe3rd', '#PAS17', 'Queen of Rap', '#CEO2017', '#TurnAMC', '#MyEvilTwinWould'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'truncated': False, 'text': 'RT @ManqobaB1: Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.', 'in_reply_to_status_id': None, 'geo': None, 'place': None, 'contributors': None, 'retweet_count': 2, 'id': 876383619144704000, 'in_reply_to_screen_name': None, 'is_quote_status': False, 'retweeted': False, 'favorited': False, 'user': {'has_extended_profile': False, 'profile_text_color': '333333', 'profile_background_image_url_https': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874567299054710784/rZ6HdaOK_normal.jpg', 'profile_link_color': '1DA1F2', 'verified': False, 'url': None, 'id': 873810603571388416, 'default_profile': True, 'favourites_count': 115, 'friends_count': 30, 'default_profile_image': False, 'screen_name': 'wX96DAOfdUiNrNE', 'notifications': False, 'profile_background_image_url': None, 'translator_type': 'none', 'is_translator': False, 'is_translation_enabled': False, 'listed_count': 0, 'profile_sidebar_fill_color': 'DDEEF6', 'id_str': '873810603571388416', 'geo_enabled': False, 'utc_offset': None, 'location': '', 'follow_request_sent': False, 'protected': False, 'statuses_count': 133, 'description': '', 'following': False, 'profile_background_color': 'F5F8FA', 'contributors_enabled': False, 'followers_count': 1, 'profile_use_background_image': True, 'name': 'Faith Hudson', 'time_zone': None, 'entities': {'description': {'urls': []}}, 'profile_background_tile': False, 'created_at': 'Sun Jun 11 07:54:17 +0000 2017', 'lang': 'ru', 'profile_sidebar_border_color': 'C0DEED', 'profile_image_url': 'http://pbs.twimg.com/profile_images/874567299054710784/rZ6HdaOK_normal.jpg'}, 'retweeted_status': {'truncated': False, 'text': 'Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.', 'in_reply_to_status_id': None, 'geo': None, 'place': None, 'contributors': None, 'retweet_count': 2, 'favorite_count': 1, 'id': 861679147403419649, 'in_reply_to_screen_name': None, 'is_quote_status': False, 'favorited': False, 'user': {'has_extended_profile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/714525391067693057/1462772727', 'profile_text_color': '333333', 'profile_background_image_url_https': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/857969482622525440/_Lgse2py_normal.jpg', 'profile_link_color': '1DA1F2', 'verified': False, 'url': None, 'id': 714525391067693057, 'default_profile': True, 'favourites_count': 10, 'friends_count': 140, 'default_profile_image': False, 'screen_name': 'ManqobaB1', 'notifications': False, 'profile_background_image_url': None, 'translator_type': 'none', 'is_translator': False, 'is_translation_enabled': False, 'listed_count': 0, 'profile_sidebar_fill_color': 'DDEEF6', 'id_str': '714525391067693057', 'geo_enabled': False, 'utc_offset': None, 'location': 'Secunda', 'follow_request_sent': False, 'protected': False, 'statuses_count': 94, 'description': "Embalenhle,kas' lam'...yes I'm from the ghetto", 'following': False, 'profile_background_color': 'F5F8FA', 'contributors_enabled': False, 'followers_count': 22, 'profile_use_background_image': True, 'name': 'Manqoba', 'time_zone': None, 'entities': {'description': {'urls': []}}, 'profile_background_tile': False, 'created_at': 'Mon Mar 28 18:51:43 +0000 2016', 'lang': 'en', 'profile_sidebar_border_color': 'C0DEED', 'profile_image_url': 'http://pbs.twimg.com/profile_images/857969482622525440/_Lgse2py_normal.jpg'}, 'retweeted': False, 'id_str': '861679147403419649', 'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>', 'coordinates': None, 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'entities': {'user_mentions': [{'screen_name': 'Trevornoah', 'id': 46335511, 'id_str': '46335511', 'name': 'Trevor Noah', 'indices': [19, 30]}], 'hashtags': [{'indices': [55, 65], 'text': 'MTVAwards'}], 'symbols': [], 'urls': []}, 'in_reply_to_user_id_str': None, 'created_at': 'Mon May 08 20:28:12  ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 69

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @ManqobaB1: Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.',
#  'RT @PureblizzBeauty: The MTV Awards Red Carpet Was Packed With Style #MTVAwards https://t.co/llVrM0XjIZ',
#  'RT @HogwartsTM: El discurso de Emma Watson en los MTV Movie Awards #MTVAwards\nhttps://t.co/IFcCYWOKTr',
#  "@vannythefangirl Hey @vannythefangirl! Thanks for joining us on #MTVAwards, we've got something for you, 🍿 + 🎟! Ema… https://t.co/M4K5vyHpPg",
#  'RT @FearlessInkSA1: @FearlessInkSA1 Music Video for #ThroughTheCity coming out on 16 June 2017. #MTVBase #MTVAwards #MTVNews #TraceRequest…',
#  "@MohamadJazlann Hey! we heard ya from the #MTVAwards &amp; we've got something special for you! 🍿Do kindly email us @ contest@mtvasia.com! 😉",
#  'RT @Lern_Cabello96: Significado de Mulherão da POHA: \n#MTVAwards https://t.co/Q3pQXNkp0M',
#  'RT @adanballou: 😍VOTE 4 YOUR FAV ♥️👜\n👉 https://t.co/EWEzALONVD\n#fashion #style #handbags #Fashionable #MTVAwards #24mayo #Justin4MMVA #bant…',
#  'RT @Clexaever1: ONE RT = 1 VOTE\n\n#Clexa for #MTVAwards #SOTY2017 @MTV @MTVFandom https://t.co/6ZDrNvCzhM',
#  'RT @lawrenceslight: QUE ELLOS HAYAN PRESENTADO EL PREMIO HACE TODO PERFECTO #MTVAwards https://t.co/2SSiGOJnpG',
#  'RT @AjionaAlexus: Reunited with my #13reasonswhy family tomorrow @mtv #mtvawards tune in! 8/7c 💃🏽 https://t.co/RA1aTV50Rh',
#  'RT @opfavestyles: Cara Delevingne SLAYED #MTVAwards https://t.co/byP0OtUrji',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @adanballou: 😍VOTE 4 YOUR FAV ♥️👜\n👉 https://t.co/EWEzALONVD\n#fashion #style #handbags #Fashionable #MTVAwards #24mayo #Justin4MMVA #bant…',
#  'RT @MTV: Don’t turn off the lights during this brand new clip of "IT" from the #MTVAwards airing right now! https://t.co/2rTf7HcATO',
#  'RT @MTVteenwolf: Watch the #TeenWolf sneak during the #MTVAwards festival stream tomorrow @ 5/4c at https://t.co/evVhqK0qK7 and the main sh…',
#  'RT @MTVteenwolf: Watch the #TeenWolf sneak during the #MTVAwards festival stream tomorrow @ 5/4c at https://t.co/evVhqK0qK7 and the main sh…',
#  'RT @lizakoshy: im partnering with @MTV &amp; @mmschocolate to give away tickets to the #MTVAwards! stalk my IG story tmrw to enter! https://t.c…',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  "RT @MTV: The creative directors of the #MTVAwards share a little sneak of what you can expect at tonight's show 👀 https://t.co/HVvyeVUQEm",
#  'RT @BellaTwins: ❤ U @JohnCena #MTVAwards https://t.co/XoVs31ODky',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @lilyachty: Keeping it fresh for the #MTVAwards! Tune in Sun. May 7 at 8/7c on @MTV &amp; catch the nominees &amp; performers here!\xa0https://t.co…',
#  'RT @MTV: BE STILL, MY HEART ❤️ #MTVAwards https://t.co/oYKEY3v8jN',
#  'RT @GalGadot: Hey everyone – I’ll be at the @MTVAwards tomorrow with a ‘wonder’-ful surprise…#WonderWoman 😉 #MTVAwards @WonderWomanFilm htt…',
#  'RT @purpxsey: #MTVAwards https://t.co/iTomzz265e',
#  'RT @h4rryindie: ES EL AMOR DE MI VIDA YO YA LO CONFIRMÉ #MTVAwards https://t.co/k6WYDclwUl',
#  'RT @h4rryindie: el cast de 13 reasons why es tan hermoso me hacen mal #MTVAwards https://t.co/iKfvhJgjIW',
#  'RT @noahcyrus: #mtvawards ⛈❄️🌧 https://t.co/fU91BzvX3d',
#  'RT @MTV: Get a peek at the upcoming Tupac biopic, All Eyez On Me (@alleyezmovie), w/ this exclusive clip from the #MTVAwards--airing tonigh…',
#  '#MTVAwards \U0001f923 https://t.co/HPFGFWSq2C',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'RT @lilyachty: Keeping it fresh for the #MTVAwards! Tune in Sun. May 7 at 8/7c on @MTV &amp; catch the nominees &amp; performers here!\xa0https://t.co…',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @chrissyteigen: Yes, I do my own stunts. New episode of @spikelsb tonight before the #mtvawards at 7:30pm EST! @zendaya vs @TomHolland19…',
#  'RT @chrissyteigen: Yes, I do my own stunts. New episode of @spikelsb tonight before the #mtvawards at 7:30pm EST! @zendaya vs @TomHolland19…',
#  'RT @boysftme: Brandon Flynn\n\n#MTVAwards https://t.co/wCI4m2APwW',
#  'RT @MTVLA: ¿Viste #MTVAwards? Entonces no te perdiste el increíble spot de los #PremiosMTVMIAW con @lelepons y @ElJuanpaZurita #Genitallica…',
#  'RT @MTVLA: Hablando de #ZURIPONSENLOSMTVMIAW ¿ya votaron por @lelepons y @ElJuanpaZurita a los #PremiosMTVMIAW? 😏 #MTVAwards https://t.co/9…',
#  'RT @stilesmarin: MOOD: #MTVAwards https://t.co/BrDsCVg3kK',
#  'RT @stilesmarin: MOOD: #MTVAwards https://t.co/BrDsCVg3kK',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  "RT @MTV: Dropped by @JBALVIN, @Camila_Cabello, and @Pitbull's #MTVAwards rehearsal and it's 🔥🔥🔥 Don't miss their performance tomorrow at 8/…",
#  'RT @Camila_Cabello: GUYYS!! So excited to perform "Hey Ma" w @pitbull and @JBALVIN , see you tonight at 8/7c on @MTV! #MTVAwards https://t.…',
#  'RT @MTVNews: ✨ @Camila_Cabello gives a sneak peek at her #MTVAwards rehearsal with @Pitbull and @JBALVIN 🔥 see their full performance tonig…',
#  'RT @MTVNews: 🔥 @Camila_Cabello takes us through what to expect from her #MTVAwards performance with @Pitbull &amp; @JBALVIN | watch them tonigh…',
#  "RT @CCabelloNews: Camila on @HugoGloss' Instagram story #MTVAwards https://t.co/aVar13OeIb",
#  'RT @Z100NewYork: Hey #harmonizers can we talk about our girl @Camila_Cabello just owning the #MTVAwards - @Shelley_Rome https://t.co/qRDJgT…',
#  "RT @MTV: Okay, but @JBALVIN + @Camila_Cabello + @pitbull's #MTVAwards performance was 🔥🔥🔥 https://t.co/gck2e8NdgV",
#  'RT @MTVLA: Ese momento cuando @Camila_Cabello incendió los #MTVAwards 😍 https://t.co/eti4fkMeGn',
#  'RT @extratv: The QUEEN takes the stage! ❤️ @Camila_Cabello #MTVawards https://t.co/9Y9BenzpiL',
#  'RT @EiProfeta: Emma Watson emociona con un precioso discurso en los #MTVAwards. https://t.co/op063RbUFq',
#  'Miss his long hairs so freaking much😭😭😭😭\n#MTVAwards one direction https://t.co/JU0Erm7pZp',
#  'RT @PeytonList: Post rain #MTVAwards https://t.co/UnoizJRx8D',
#  'RT @ITMovieOfficial: Check out the horrifying #ITMovie exclusive clip from the #MTVAwards last night.🎈 https://t.co/FGZ6ERw0EN',
#  'RT @chrissyteigen: Yes, I do my own stunts. New episode of @spikelsb tonight before the #mtvawards at 7:30pm EST! @zendaya vs @TomHolland19…',
#  'RT @chrissyteigen: Yes, I do my own stunts. New episode of @spikelsb tonight before the #mtvawards at 7:30pm EST! @zendaya vs @TomHolland19…',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'RT @teenwolfbr: Tyler Posey na chuva atendendo os fãs no red carpet do #MTVAwards https://t.co/iIP3DrjCRi',
#  'RT @teenwolfbr: Tyler Posey no red carpet do #MTVAwards https://t.co/8iMl5tOgKE',
#  'RT @teenwolfbr: Tyler Posey e Holland Roden no #MTVAwards https://t.co/w8O4t3E5Nw',
#  'RT @teenwolfbr: Chovendo muito no red carpet do #mtvawards mas isso não é um problema para Tyler Posey KKKK https://t.co/waqc7efjvL',
#  'RT @PeytonList: Post rain #MTVAwards https://t.co/UnoizJRx8D',
#  'RT @teenwolfbr: Chovendo muito no red carpet do #mtvawards mas isso não é um problema para Tyler Posey KKKK https://t.co/waqc7efjvL',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'RT @boysftme: Zac Efron \n\n#MTVAwards https://t.co/eKVTWliB5J',
#  'RT @smootherbeauty: Vuestra Blossom favorita. #MTVAwards https://t.co/TuPlVjZCOe',
#  "RT @MTV: can't forget twenty one pilots' epic performance in 2014!!!! #mtvawards https://t.co/lH012ZDZuc",
#  'RT @MTVteenwolf: I AM SO EXCITED 😍 Look out for your faves today at the #MTVAwards beginning at 8/7c! https://t.co/grhaznhN9a',
#  'RT @BeaMillerOnline: Bea performing "Young Blood" at #MTVAwards festival #2 (via 1iota IG ) https://t.co/PgCl9gGJWp',
#  'RT @boysftme: Zac Efron \n\n#MTVAwards https://t.co/eKVTWliB5J',
#  'RT @MTV: 😍 @RossButler will be attending the MTV Movie &amp; TV Awards this Sunday at 8/7c. #MTVAwards https://t.co/JOR2zjp6vl',
#  'RT @MTV: Oh wow, hiiiiiii @RossButler. #MTVAwards https://t.co/ccvPQjQiNw',
#  'RT @chrissyteigen: Yes, I do my own stunts. New episode of @spikelsb tonight before the #mtvawards at 7:30pm EST! @zendaya vs @TomHolland19…',
#  '#MTVAwards..\n\nMitos',
#  'RT @MTV: Seeing the @Stranger_Things cast with the @13ReasonsWhy cast at the #MTVAwards is too much for my heart to handle 💗 https://t.co/p…',
#  'RT @Scoopla: HOW CUTE ARE @RealHughJackman &amp; @DafneKeen?!  #MTVAwards https://t.co/0Htb0bE7JO',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  '#bcfc #bbctbq https://t.co/Wx8ShbNqMt #Retweet #Win #swfc #csgogiveaway #onthisday #hounslow #myinspiration #mtvawards #freebiefriday',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @CamilaManiaBR: Performance completa de "Hey Ma" no #MTVAwards\n\n#PREMIOSMTVMIAW #MTVINSTAGLCABELLO https://t.co/cLbWMlZyXo',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @archivekarla: Backstage #MTVAwards https://t.co/ejHP1f2S6K',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @13ReasonsOnly: Brandon Flynn was looking all types of fine tonight #MTVAwards https://t.co/9A8Ogvk9w9',
#  'RT @ANTMVH1: L👏I👏T👏E👏R👏A👏L👏L👏Y us during the #MTVAwards next week Sunday May 7 at 8/7c on @MTV… https://t.co/b2tGZZnYRa',
#  'RT @MTV: BE STILL, MY HEART ❤️ #MTVAwards https://t.co/oYKEY3v8jN',
#  "RT @GabrielConte: We're heading to the #MTVAwards with @realisadiamond :) We loved partnering with them and can't wait for the red carpet!…",
#  'RT @GalGadot: Hey everyone – I’ll be at the @MTVAwards tomorrow with a ‘wonder’-ful surprise…#WonderWoman 😉 #MTVAwards @WonderWomanFilm htt…',
#  'RT @larracuentebr: 🎥 | Brandon, Jazmin e Ross deixando os #MTVAwards https://t.co/b93JVQDda3',
#  'RT @fabys_0505: Se lo merecía James McAvoy #MTVAwards']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "truncated": false,
#  "text": "RT @ManqobaB1: Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.",
#  "in_reply_to_status_id": null,
#  "geo": null,
#  "place": null,
#  "contributors": null,
#  "retweet_count": 2,
#  "id": 876383619144704000,
#  "in_reply_to_screen_name": null,
#  "is_quote_status": false,
#  "retweeted": false,
#  "favorited": false,
#  "user": {
#   "has_extended_profile": false,
#   "profile_text_color": "333333",
#   "profile_background_image_url_https": null,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/874567299054710784/rZ6HdaOK_normal.jpg",
#   "profile_link_color": "1DA1F2",
#   "verified": false,
#   "url": null,
#   "id": 873810603571388416,
#   "default_profile": true,
#   "favourites_count": 115,
#   "friends_count": 30,
#   "default_profile_image": false,
#   "screen_name": "wX96DAOfdUiNrNE",
#   "notifications": false,
#   "profile_background_image_url": null,
#   "translator_type": "none",
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "listed_count": 0,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "id_str": "873810603571388416",
#   "geo_enabled": false,
#   "utc_offset": null,
#   "location": "",
#   "follow_request_sent": false,
#   "protected": false,
#   "statuses_count": 133,
#   "description": "",
#   "following": false,
#   "profile_background_color": "F5F8FA",
#   "contributors_enabled": false,
#   "followers_count": 1,
#   "profile_use_background_image": true,
#   "name": "Faith Hudson",
#   "time_zone": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "profile_background_tile": false,
#   "created_at": "Sun Jun 11 07:54:17 +0000 2017",
#   "lang": "ru",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/874567299054710784/rZ6HdaOK_normal.jpg"
#  },
#  "retweeted_status": {
#   "truncated": false,
#   "text": "Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.",
#   "in_reply_to_status_id": null,
#   "geo": null,
#   "place": null,
#   "contributors": null,
#   "retweet_count": 2,
#   "favorite_count": 1,
#   "id": 861679147403419649,
#   "in_reply_to_screen_name": null,
#   "is_quote_status": false,
#   "favorited": false,
#   "user": {
#    "has_extended_profile": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/714525391067693057/1462772727",
#    "profile_text_color": "333333",
#    "profile_background_image_url_https": null,
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/857969482622525440/_Lgse2py_normal.jpg",
#    "profile_link_color": "1DA1F2",
#    "verified": false,
#    "url": null,
#    "id": 714525391067693057,
#    "default_profile": true,
#    "favourites_count": 10,
#    "friends_count": 140,
#    "default_profile_image": false,
#    "screen_name": "ManqobaB1",
#    "notifications": false,
#    "profile_background_image_url": null,
#    "translator_type": "none",
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "listed_count": 0,
#    "profile_sidebar_fill_color": "DDEEF6",
#    "id_str": "714525391067693057",
#    "geo_enabled": false,
#    "utc_offset": null,
#    "location": "Secunda",
#    "follow_request_sent": false,
#    "protected": false,
#    "statuses_count": 94,
#    "description": "Embalenhle,kas' lam'...yes I'm from the ghetto",
#    "following": false,
#    "profile_background_color": "F5F8FA",
#    "contributors_enabled": false,
#    "followers_count": 22,
#    "profile_use_background_image": true,
#    "name": "Manqoba",
#    "time_zone": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "profile_background_tile": false,
#    "created_at": "Mon Mar 28 18:51:43 +0000 2016",
#    "lang": "en",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/857969482622525440/_Lgse2py_normal.jpg"
#   },
#   "retweeted": false,
#   "id_str": "861679147403419649",
#   "source": "<a href=\"http://blackberry.com/twitter\" rel=\"nofollow\">Twitter for BlackBerry\u00ae</a>",
#   "coordinates": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_status_id_str": null,
#   "entities": {
#    "user_mentions": [
#     {
#      "screen_name": "Trevornoah",
#      "id": 46335511,
#      "id_str": "46335511",
#      "name": "Trevor Noah",
#      "indices": [
#       19,
#       30
#      ]
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       55,
#       65
#      ],
#      "text": "MTVAwards"
#     }
#    ],
#    "symbols": [],
#    "urls": []
#   },
#   "in_reply_to_user_id_str": null,
#   "created_at": "Mon May 08 20:28:12 +0000 2017",
#   "lang": "en",
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "id_str": "876383619144704000",
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "coordinates": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_status_id_str": null,
#  "entities": {
#   "user_mentions": [
#    {
#     "screen_name": "ManqobaB1",
#     "id": 714525391067693057,
#     "id_str": "714525391067693057",
#     "name": "Manqoba",
#     "indices": [
#      3,
#      13
#     ]
#    },
#    {
#     "screen_name": "Trevornoah",
#     "id": 46335511,
#     "id_str": "46335511",
#     "name": "Trevor Noah",
#     "indices": [
#      34,
#      45
#     ]
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      70,
#      80
#     ],
#     "text": "MTVAwards"
#    }
#   ],
#   "symbols": [],
#   "urls": []
#  },
#  "in_reply_to_user_id_str": null,
#  "created_at": "Sun Jun 18 10:18:31 +0000 2017",
#  "lang": "en",
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 2
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @ManqobaB1: Congratulations to @Trevornoah in winning Best Host on #MTVAwards well deserved.",
#  "RT @PureblizzBeauty: The MTV Awards Red Carpet Was Packed With Style #MTVAwards https://t.co/llVrM0XjIZ",
#  "RT @HogwartsTM: El discurso de Emma Watson en los MTV Movie Awards #MTVAwards\nhttps://t.co/IFcCYWOKTr",
#  "@vannythefangirl Hey @vannythefangirl! Thanks for joining us on #MTVAwards, we've got something for you, \ud83c\udf7f + \ud83c\udf9f! Ema\u2026 https://t.co/M4K5vyHpPg",
#  "RT @FearlessInkSA1: @FearlessInkSA1 Music Video for #ThroughTheCity coming out on 16 June 2017. #MTVBase #MTVAwards #MTVNews #TraceRequest\u2026"
# ]
# [
#  "ManqobaB1",
#  "Trevornoah",
#  "PureblizzBeauty",
#  "HogwartsTM",
#  "vannythefangirl"
# ]
# [
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards",
#  "ThroughTheCity"
# ]
# [
#  "RT",
#  "@ManqobaB1:",
#  "Congratulations",
#  "to",
#  "@Trevornoah"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
